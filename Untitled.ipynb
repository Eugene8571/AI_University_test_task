# %%
import sys
from main import History
from main import random_sequence, random_score

# %%
h = History()
for i in range(100):
    sequence = random_sequence()
    score = ()
    h.set_history(sequence, score)

# %%
filepath = 'save/h1.txt'
h.save_history(filepath)

# %%
A = h.load_history(filepath)

# %%
print(len(A))
print(sys.getsizeof(A))
# Out:
# 50000
# 203244

# %%
h = History()
c = 0

while sys.getsizeof(h.history_arr) < 10**6:
    c += 1
    sequence = random_sequence()
    score = ()
    h.set_history(sequence, score)
print(c, len(h.history_arr), sys.getsizeof(h.history_arr))
# Out:
# 500 250000 1000028
