# %%
import sys
import time
from main import *

# %% [markdown]
# Тэст 1. Прогон до 3кб, сохранение разультата.

# %%
filepath = 'save/h1.csv'
t1 = time.time()

h = History()

test_func(h, 3000)

h.save_history(filepath)
# Out:
# Время выполнения  0.5736494064331055
# Кол-во дубликатов 0

# %% [markdown]
# Тест 2. Загрузка и прогон до 5кб.

# %%
h.load_history(filepath)

test_func(h, 5000)
# Out:
# Время выполнения  0.006001472473144531
# Кол-во дубликатов 0
